# %% [markdown]
# # Importing Data Set

# %%
import pandas as pd
df = pd.read_csv("diabetic_data.csv")
df = df.drop(["weight", "payer_code", "medical_specialty"], axis=1)

# %% [markdown]
# ## Probabilities:
# ### Get the probability of being readmitted into the hospital before or after 30 days, or not at all if a certain condition applies:
# #### if diabetic
# #### by age
# #### by race
# #### by gender
# #### by type of admission
# #### time in hospital
# #### by diagnostic
# #### glucose serum test result
# #### by A1 Results
# #### drug treatment a apatient is under
# #### if patient has been changed of meds

# %%
df1 = pd.DataFrame(df, columns=["diabetesMed_No", "diabetesMed_No", "readmitted_<30", "readmitted_>30", "readmitted_NO"])

# %%
df.isna().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# ...

# %%
df
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# ...

# %%
df["readmitted"].value_counts(dropna=False, normalize=True)
# Out:
# NO     0.539119
# >30    0.349282
# <30    0.111599
# Name: readmitted, dtype: float64

# %%
#def mapping(data,feature):
#    featureMap=dict()
#    count=0
#    for i in sorted(data[feature].unique(),reverse=True):
#        featureMap[i]=count
#        count=count+1
#    data[feature]=data[feature].map(featureMap)
#    return data
#
#

dummies = pd.get_dummies(df)
dummies
# Out:
#         encounter_id  patient_nbr  admission_type_id  \
# 0            2278392      8222157                  6
# 1             149190     55629189                  1
# 2              64410     86047875                  1
# 3             500364     82442376                  1
# 4              16680     42519267                  1
# ...              ...          ...                ...
# 101761     443847548    100162476                  1
# 101762     443847782     74694222                  1
# 101763     443854148     41088789                  1
# 101764     443857166     31693671                  2
# 101765     443867222    175429310                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                             25                    1                 1
# 1                              1                    7                 3
# 2                              1                    7                 2
# ...

# %%
dummies
# Out:
#         encounter_id  patient_nbr  admission_type_id  \
# 0            2278392      8222157                  6
# 1             149190     55629189                  1
# 2              64410     86047875                  1
# 3             500364     82442376                  1
# 4              16680     42519267                  1
# ...              ...          ...                ...
# 101761     443847548    100162476                  1
# 101762     443847782     74694222                  1
# 101763     443854148     41088789                  1
# 101764     443857166     31693671                  2
# 101765     443867222    175429310                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                             25                    1                 1
# 1                              1                    7                 3
# 2                              1                    7                 2
# ...

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#plt.scatter(dummies["diabetesMed_No"], dummies["readmitted_<30"])
#plt.scatter(dummies["diabetesMed_No"], dummies["readmitted_>30"])
#plt.scatter(dummies["diabetesMed_No"], dummies["readmitted_NO"])
#plt.scatter(dummies["diabetesMed_Yes"], dummies["readmitted_<30"])#plt.scatter(dummies["diabetesMed_Yes"], dummies["readmitted_>30"])
#plt.scatter(dummies["diabetesMed_Yes"], dummies["readmitted_NO"])

# %%
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split

df1 = pd.DataFrame(dummies, columns=["diabetesMed_No", "diabetesMed_Yes", "readmitted_<30", "readmitted_>30", "readmitted_NO"])
df1
y = df1['readmitted_NO']
def tipoDePrediccion(df):
    for col in df:
        return col

X = tipoDePrediccion(df1)
#X = df1[["diabetesMed_Yes", "diabetesMed_No"]]





X
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
#print(X.shape,y.shape)
#print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
#y_train.value_counts()[1] / len(y_train)
# Out:
# 'diabetesMed_No'

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression().fit(X_train, y_train)
clf
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
y_pred = clf.predict(X_test)  # esta es mi y predicha
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.5418099636435099
# [[    0     0  2301]
#  [    0     0  7025]
#  [    0     0 11028]]

# %%
clf.score(X_train, y_train)
# Out:
# 0.5384464206750847

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LassoCV, LinearRegression
from sklearn.pipeline import make_pipeline

# %%
from sklearn.neighbors import KNeighborsClassifier

neigh = KNeighborsClassifier(n_neighbors=3)
Nclf = neigh.fit(X_train,y_train)
Nclf

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import *
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.model_selection import cross_val_score
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier, GradientBoostingClassifier, RandomForestClassifier, HistGradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

# %matplotlib inline

# %%
models = {
#    "Linear": LinearSVC(max_iter=300),
#    "neighbors": KNeighborsClassifier(),
#    "histboosting": HistGradientBoostingClassifier(),
#    "histboosting0.25": HistGradientBoostingClassifier(learning_rate=0.25),
#    "histRegressor": HistGradientBoostingRegressor(),
#    "histRegressor0.20": HistGradientBoostingRegressor(learning_rate=0.2)
#    "forest300,50": RandomForestClassifier(n_estimators=300, max_depth=10),#    "Gradientboosting" : GradientBoostingClassifier(learning_rate=0.2)
}
for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=30)
    print(f"{name} accuracy => {np.mean(scores)}")

# %% [markdown]
# #### Linear accuracy => 0.5391191597295207
# #### neighbors accuracy => 0.4467201972661065
# #### forest300,50 accuracy => 0.5391191597295207
# #### Gradientboosting accuracy => 0.5391191597295207

# %%
dummies

# %%
df.dtypes

# %%
df["insulin"].value_counts(dropna=False, normalize=True)

# %%
df.columns

# %%
df["max_glu_serum"].value_counts(dropna=False, normalize=True)

# %%
df.isna().sum()
#df.drop["medical_specialty", "weight", "payer_code", "metformin", ]

# %%
df["nateglinide"].value_counts(dropna=False, normalize=True)

# %%
df["repaglinide"].value_counts(dropna=False, normalize=True)

# %%
df["metformin"].value_counts(dropna=False, normalize=True)

# %% [markdown]
# # No limpiar

# %%
df["max_glu_serum"].value_counts()

# %% [markdown]
# # No limpiar

# %%
df["change"].value_counts()
print ("")

# %% [markdown]
# # Limpiar al segundo

# %%
df["A1Cresult"].value_counts()

# %% [markdown]
# # Limpiar al primero(quitar no)

# %%
df["insulin"].value_counts()

# %%
import seaborn as sns
corr = df._get_numeric_data().corr()
corr_matrix = corr
sns.heatmap(corr_matrix)
corr
